# %%
import yfinance as yf

# %%
sectors = [
    "materials",
    "communication-services",
    "consumer-staples",
    "consumer-discretionary",
    "energy",
    "financials",
    "healthcare",
    "industrials",
    "real-estate",
    "technology",
    "utilities"
]

# %%
dat = yf.Ticker("MSFT")
dat.info

# yfinance.Sector(key, session=None)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 dat = yf.Ticker("MSFT")
# ----> 2 dat.info
#
# File ~\anaconda3\Lib\site-packages\yfinance\ticker.py:142, in Ticker.info(self)
#     140 @property
#     141 def info(self) -> dict:
# --> 142     return self.get_info()
#
# File ~\anaconda3\Lib\site-packages\yfinance\base.py:1678, in TickerBase.get_info(self, proxy)
#    1676 def get_info(self, proxy=None) -> dict:
#    1677     self._quote.proxy = proxy
# -> 1678     data = self._quote.info
#    1679     return data
#
# File ~\anaconda3\Lib\site-packages\yfinance\scrapers\quote.py:571, in Quote.info(self)
#     568 @property
#     569 def info(self) -> dict:
#     570     if self._info is None:
# --> 571         self._fetch(self.proxy)
#     572         self._fetch_complementary(self.proxy)
#     574     return self._info
#
# ...
