# %%
import requests
# import bs4
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
BASE_URL = "https://stockanalysis.com"
HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

# %%
# res = requests.get(BASE_URL + "/stocks/industry/")
# res.raise_for_status()

# %%
soup = get_soup(BASE_URL + "/stocks/industry/")

# %%
def get_subsector_urls():
    counter = 0
    arr_sectors = []
    sector_tables = soup.select(".styled-scrollbar > table")
    # print (len(sector_tables))
    
    for t in soup.select(".controls > .title-group"):
        if counter <= 100:
            href = t.select('a')[0]['href']
            sector_key = href.replace("/stocks/sector/", "").replace("/", "")
            
            sector_table = sector_tables[counter]
            subsector_hrefs = [x['href'].replace("/stocks/industry/", "").replace("/", "") for x in sector_table.select("tbody > tr > td:first-child > a")]
            subsector_hrefs = [x for x in tuple_subsector]
            
            arr_sectors.append({"sector_name": sector_key, "urls": subsector_hrefs})
          
        counter += 1

    return arr_sectors

arr_sectors = get_subsector_urls()
g_sub_sector_soup = None

# %%
def scrape_sectors(sectors):
    counter2 = 0
    df = None
    for sector in arr_sectors:
        if counter2 <= 0:
            print ('Getting stocks for ', sector.get("sector_name"))
            for url in sector.get("urls"):
                df = scrape_sector(url)
                break
        counter2 += 1
    return df

def scrape_sector(url):
    print ('subsector url', url)
    df = scrape_page_for_tickers(url)
    return df
    

def scrape_page_for_tickers(url):
    global g_sub_sector_soup
    if g_sub_sector_soup is None:
        g_sub_sector_soup = get_soup(url)
        print('getting soup')

    # page 1
    soup = g_sub_sector_soup
    subsector_name = url[url.rindex("/") + 1:]
    
    
    total_pages = get_total_pages(soup)
    print(f"{subsector_name}: {total_pages} pages found")
    
    all_rows = []
    
    # scrape page 1
    all_rows.extend(scrape_page(url, subsector_name))
    # # scrape remaining pages
    for page_num in range(2, total_pages + 1):
        page_url = f"{url}?p={page_num}"
        print(f"Scraping page {page_num}...")
    
        rows = scrape_page(page_url, subsector_name)
        all_rows.extend(rows)
    
    df = pd.DataFrame(all_rows)
    
    # remove duplicates if any
    df.drop_duplicates(subset=["ticker"], inplace=True)
    
    # save csv
    file_name = f"{sector_name}.csv"
    df.to_csv(file_name, index=False)
    
    print(f"Saved {len(df)} stocks to {file_name}")
    
    return df
    

df = scrape_sectors(arr_sectors)
df
# Out:
# Getting stocks for  healthcare
# subsector url https://stockanalysis.com/stocks/industry/biotechnology
# biotechnology: 2 pages found
# https://stockanalysis.com/stocks/industry/biotechnology
# Scraping page 2...
# https://stockanalysis.com/stocks/industry/biotechnology?p=2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[235], line 59
#      54     print(f"Saved {len(df)} stocks to {file_name}")
#      56     return df
# ---> 59 df = scrape_sectors(arr_sectors)
#      60 df
#
# Cell In[235], line 8, in scrape_sectors(sectors)
#       6     print ('Getting stocks for ', sector.get("sector_name"))
#       7     for url in sector.get("urls"):
# ----> 8         df = scrape_sector(url)
#       9         break
#      10 counter2 += 1
#
# Cell In[235], line 15, in scrape_sector(url)
#      13 def scrape_sector(url):
#      14     print ('subsector url', url)
# ...

# %%
def scrape_page(url, sector_name):
    soup = get_soup(url)
    print (url)

    rows = []

    ticker_cells = soup.find_all("td", class_="sym")

    for ticker_cell in ticker_cells:

        a = ticker_cell.find("a")
        if not a:
            continue

        ticker = a.get_text(strip=True)

        company_cell = ticker_cell.find_next_sibling("td", class_="slw")
        company_name = company_cell.get_text(strip=True) if company_cell else ""

        rows.append({
            "ticker": ticker,
            "company_name": company_name,
            "sub_sector_name": sector_name
        })

    return rows
    
def get_total_pages(soup):
    
    nav = soup.find_all("nav")
    
    if len(nav) == 2:
        return 1
        
    if not nav:
        return 1

    nav = nav[2]
    
    # Find the outer span that contains pagination text
    page_span = nav.find("span", class_="whitespace-nowrap")

    if not page_span:
        return 1

    text = page_span.get_text(" ", strip=True)
    # Example result: "Page 1 of 2"

    match = re.search(r"of\s+(\d+)", text)

    if match:
        return int(match.group(1))

    return 1

# %%
def get_soup(url):
    r = requests.get(url, headers=HEADERS, timeout=20)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

# %%
table_1 = soup.select(".styled-scrollbar > table")[1]
table_1.select("tr:not(:first-child)")
# Out:
# [<tr class="svelte-1vx0bpj"><!--[--><!--[--><td class="svelte-1vx0bpj"><!-- --><a href="/stocks/industry/shell-companies/">Shell Companies</a><!-- --></td><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- -->291<!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- -->76.26B<!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- -->-<!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- -->-<!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- -->-232.03%<!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- --><span class="rr">-0.34%</span><!-- --></td><!--]--><!--]--><!--]--><!--[!--><!--[--><!--[--><td class="tr svelte-1vx0bpj"><!-- --><span class="rr">-1.40%</span><!-- --></td><!--]--><!--]--><!--]--><!--]--></tr>,
# ...
