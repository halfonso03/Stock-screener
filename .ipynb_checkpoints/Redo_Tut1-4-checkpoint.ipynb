# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
# from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import time
from datetime import datetime, timezone
# import mplfinance as mpf # Matplotlib finance
import os
from os import listdir
from os.path import isfile, join
from pathlib import Path

import requests
import json
import csv

# %%
# Define path to files
# PATH = "C:/Udemy/2026-Python-EricBanas/Banas/Section53_Finance/redo/"
PATH = "D:/Udemy/2026-Python3-ErikBanas/Section53_PythonForFinance/redo/"

# Start date defaults
S_YEAR = 2017
S_MONTH = 1
S_DAY = 3
S_DATE_STR = f"{S_YEAR}-0{S_MONTH}-0{S_DAY}"
S_DATE_DATETIME = datetime(S_YEAR, S_MONTH, S_DAY)

# End date defaults
E_YEAR = 2021
E_MONTH = 8
E_DAY = 19
E_DATE_STR = f"{E_YEAR}-0{E_MONTH}-{E_DAY}"
E_DATE_DATETIME = datetime(E_YEAR, E_MONTH, E_DAY)

missing_tickers = ['AES']
tickers_to_skip = ['FIT']

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJ1dWlkIjoiaGVjdG9yYXdzQHlhaG9vLmNvbSIsInBsYW4iOiJwcm8iLCJuZXdzZmVlZF9lbmFibGVkIjp0cnVlLCJ3ZWJzb2NrZXRfc3ltYm9scyI6Miwid2Vic29ja2V0X2Nvbm5lY3Rpb25zIjoxfQ.eXXJXl0mETrgv_aITIsjl_tmT3HQ-RdsiRCw-54NWlw',
}

params = {
    'bar_type': 'hour',
    'bar_interval': '1',
    'start_date': '2020-04',
    'dadj': 'false',
    'abbr': 'false',
}

# %% [markdown]
# ## Get data from endpoint

# %%
# files = [x for x in listdir(PATH + '/converted') if isfile(join(PATH + '/converted', x))]
# converted_tickers = [os.path.splitext(x)[0] for x in files]

def save_fundamentals_for_tickers(*tickers):
    for t in tickers:
        save_fundamentals_for_ticker(t)
    
def save_fundamentals_for_ticker(ticker):

    if not os.path.exists(f"{PATH}dividends/{ticker}.json"):

        print (f'Getting fundamentals for {ticker}')
        url = f"https://api.insightsentry.com/v3/symbols/NYSE%3A{ticker}/fundamentals"
        response = call_api(url)
    
        if response.status_code != 200:
            url = f"https://api.insightsentry.com/v3/symbols/NASDAQ%3A{ticker}/fundamentals"
            response = call_api(url)

        try:
            json_data = response.json()
            # data = json['data']

            with open(f"{PATH}/dividends/{ticker}.json", "w") as f:
                json.dump(json_data, f, indent=4)

            print (f"Fundamentals for {ticker} saved.")
            # m = next((item for item in data if item["id"] == "dividend_payment_date_h"), None)
            
            # if m is not None:
            #     if len(m['value']) > 0:
            #         df = pd.DataFrame(m['value'], columns=["epoch_date"])
            #         df['date'] = df['epoch_date'].apply(lambda x: datetime.fromtimestamp(int(x)))
            #         df['date'] = df["date"].dt.normalize()
            #         df = df[['date']]
            #         df.to_csv(f'{PATH}dividends/{ticker}.csv')
        except Exception as e:
            print (f'Error getting dividend data for {ticker} {e}')

            
# save_fundamentals_for_tickers(*converted_tickers[1050:1250])


# converted_tickers.index('DDS')

# %%
save_fundamentals_for_ticker('IMO')
# Out:
# Getting fundamentals for IMO
# Fundamentals for IMO saved.

# %%
def call_api(url):
    response = requests.get(url, headers=headers)
    return response
    
def save_stock_to_json(exchange, ticker):
    # params=params, 
    # dadj=true
    # dadj=false
    # split=false
    
    adj_for = "dadj=true"

    # url = f"https://api.insightsentry.com/v3/symbols/{exchange}%3A{ticker}/series?bar_type=1d&bar_interval=1&{adj_for}&dp=3000&long_poll=false&abbr=false"
    url = f"https://api.insightsentry.com/v3/symbols/{exchange}%3A{ticker}/series?bar_type=day&bar_interval=1&extended=false&{adj_for}&dp=3000&long_poll=false&abbr=false"
    
    
    response = call_api(url)
    
    print (response.status_code)
    
    if response.status_code == 200:
        data = response.json()
        with open(f"{PATH}/downloaded/{ticker}.json", "w") as f:
            json.dump(data, f, indent=4)
            time.sleep(5)
        
        return True, response.status_code
    
    return False, response.status_code


def download_tickers(num_to_download):
    
    df_next = get_next_tickers_to_download(num_to_download)
    # df_next = pd.DataFrame( ["GNRC", "CPRT", "ODFL", "AMD", "PAYC", "CHTR", "MKC", 
    #              "PG", "PGR", "NEM", "CCI", "COG"], columns=['ticker'])
    # saved, status_code = save_stock_to_json('FRED', 'SP500')
    # df_next = pd.DataFrame(['EL'], columns=['ticker'])
    # faang_list = ["META", "AMZN", "AAPL", "NFLX", "GOOG"]
    df_next = pd.DataFrame(missing_tickers, columns=['ticker'])

    for index in range(len(df_next)):
        
        ticker = df_next.iloc[index]['ticker']
                
        if not os.path.exists(f"{PATH}downloaded/{ticker}.json"):
            
            saved, status_code = save_stock_to_json('NYSE', ticker)
            
            if not saved:
                print (f'Error getting stock data for {ticker} on NASDAQ. Status Code {status_code}. Trying NYSE...')
                
                saved, status_code = save_stock_to_json('NASDAQ', ticker)
                
                if not saved:
                    print (f'Error getting stock data for {ticker} on NYSE. Status Code {status_code}')
                    with open(f"{PATH}downloaded/{ticker}.json", "w") as f:
                        json.dump("not found", f, indent=4)
                else: 
                    print (f'{index + 1} - stock data for ' + ticker + ' saved.')
            else:
                print (f'{index + 1} - stock data for ' + ticker + ' saved.')
    
        # else:
        #     print (f"File for {ticker} already exists!")
    
    print ('DONE DOWNLOADING!')

def get_downloaded_tickers():
    files = [x for x in listdir(PATH + '/downloaded') if isfile(join(PATH + '/downloaded', x))]
    downloaded_tickers = [os.path.splitext(x)[0] for x in files]
    return downloaded_tickers
    
def get_next_tickers_to_download(num_to_dl):
    df_wil = get_wilshire_tickers()
    df_wil = df_wil.rename(columns={'ticker' : 'ticker1'})
    tickers = get_downloaded_tickers()
    df_dltickers = pd.DataFrame(np.array(tickers), columns=['ticker2'])
    
    result = pd.merge(df_wil, df_dltickers, left_on='ticker1', right_on='ticker2', how='left', suffixes=('_left', '_right'))
    result = result[result['ticker2'].isna()].sort_values(by='ticker1').head(num_to_dl)
    result = result.drop(columns=['ticker2']).rename(columns={'ticker1':'ticker'})
    return result

def get_tickers_not_converted():
        
    files = [x for x in listdir(PATH + '/downloaded') if isfile(join(PATH + '/downloaded', x)) and os.path.getsize(f'{PATH}/downloaded/{x}') > 11]
    df_downloaded_tickers = pd.DataFrame([os.path.splitext(x)[0] for x in files], columns=['ticker1'])
    
    files = [x for x in listdir(PATH + '/converted') if isfile(join(PATH + '/converted', x))]
    df_converted_tickers = pd.DataFrame( [os.path.splitext(x)[0] for x in files], columns=['ticker2'])
    
    df_not_converted = pd.merge(df_downloaded_tickers, df_converted_tickers, 
                      left_on='ticker1', 
                      right_on='ticker2', 
                      how='left', 
                      suffixes=('_left', '_right'))
    
    df = df_not_converted[df_not_converted['ticker2'].isna()]
    df = df.drop(columns=['ticker2'])
    df = df[~df['ticker1'].isin(tickers_to_skip)]
    
    return df

def get_wilshire_tickers():
    df_wilshire_tickers = pd.read_csv(PATH + 'Wilshire-5000-Stocks-New.csv')
    df_wilshire_tickers = df_wilshire_tickers.rename(columns={'Ticker':'ticker'}).drop(columns=['Company']).drop_duplicates()
    return df_wilshire_tickers

# %%
missing_tickers = ['BATL']
download_tickers(100)

convert_files_json_to_csv(*missing_tickers)
add_daily_returns_to_stocks(*missing_tickers)


# arr = get_tickers_not_converted()
# arr = [x for x in arr['ticker1'].values]
# Out:
# 400
# Error getting stock data for BATL on NASDAQ. Status Code 400. Trying NYSE...
# 400
# Error getting stock data for BATL on NYSE. Status Code 400
# DONE DOWNLOADING!
# Error in 'def convert_single_file_json_to_csv' converting BATL to csv
# Adding daily returns to BATL
# File for ticker BATL doesn't exist

# %% [markdown]
# ## Work with CSV files

# %%
def get_df_from_csv(ticker, sdate = '2021-05-01'):
    
    # Try to get the file and if it issue a warning
    try:

        if ticker not in tickers_to_skip:
            df = pd.read_csv(PATH + 'converted/' + ticker + '.csv')
            # df['date2'] = pd.DatetimeIndex(['date'])
            df = df.set_index(pd.to_datetime(df['date']))
            df.drop(columns=['date'], inplace=True)
            df = df.loc[sdate:]
            # df['company'] = sec_df[sec_df['ticker'] == ticker]['company_name'].item()
            return df
        else:
            return None
        # df = delete_unnamed_cols(df)
        
    except FileNotFoundError:
        missing_tickers.append(ticker)
        print(f"{ticker}")
        return None


def convert_files_json_to_csv(*args):
    for t in args:
        if t not in tickers_to_skip:
            convert_single_file_json_to_csv(t)

def convert_single_file_json_to_csv(ticker):
    # ticker = 'AMZN'
    json_path = f"{PATH}/downloaded/{ticker}.json"
    csv_path = f"{PATH}/converted/{ticker}.csv"
    try:
        df = pd.read_json(json_path)
        if len(df) > 0:
            print (f'Converting json for {ticker} to csv')
            df['date'] = df['series'].apply(lambda x: datetime.fromtimestamp(int(x['time'])))
            df['close'] = df['series'].apply(lambda x: x['close'])
            df['date'] = df["date"].dt.normalize()
            df = df[['date','close']]
            # df = df.sort_values("date").drop_duplicates("date", keep="last")
            df['date'] = df['date'].dt.strftime('%Y-%m-%d')
            # df['date2'] = pd.DatetimeIndex(['date'])
            df = df.set_index(pd.to_datetime(df['date']))
            df.to_csv(csv_path, index=False)
            return df
    except:
        print (f"Error in 'def convert_single_file_json_to_csv' converting {ticker} to csv")


def get_df_from_csv_all_years(ticker):
    
    # Try to get the file and if it issue a warning
    try:

        if ticker not in tickers_to_skip:
            df = pd.read_csv(PATH + 'converted/' + ticker + '.csv')
            # df['date2'] = pd.DatetimeIndex(['date'])
            df = df.set_index(pd.to_datetime(df['date']))
            df.drop(columns=['date'], inplace=True)
            return df
        else:
            return None
        # df = delete_unnamed_cols(df)
        
    except FileNotFoundError:
        missing_tickers.append(ticker)
        print(f"{ticker}")
        return None
        



def get_column_from_csv(file, col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print ('File doesnt exist')
    else:
        return df[col_name]

# %% [markdown]
# ## Add daily returns to converted CSV file

# %%
def add_daily_returns_to_stocks(*args):
    for t in args:
        if t not in tickers_to_skip:
            add_daily_returns(t)
    
def add_daily_returns(ticker):
    
    print(f"Adding daily returns to {ticker}")

    try:
        # Get a dataframe for that ticker
        stock_df = get_df_from_csv_all_years(ticker)
        
        # # Add daily return to this dataframe
        if stock_df is not None:

            if 'daily_return' in stock_df.columns:
                stock_df.drop(columns=['daily_return'], inplace=True)
                
            stock_df['daily_return'] = (stock_df['close'] / stock_df['close'].shift(1)) - 1
            stock_df.to_csv(PATH + 'converted/' + ticker + '.csv')
    
    except Exception as e: 
        print (f"Error in 'def add_daily_returns' ticker: {ticker} ------------------")
        print (e)

# %%
def plot_return_mult_stocks(investment, stock_df):
    (stock_df / stock_df.iloc[0] * investment).plot(figsize = (15,6))
    plt.show()

def merge_df_by_column_name(col_name, sdate, edate, *tickers):
    mult_df = pd.DataFrame()
    for x in tickers:
        df = get_df_from_csv(x)
        if df is not None:
            # NEW Check if your dataframe has duplicate indexes
            if not df.index.is_unique:
                # Delete duplicates 
                df = df.loc[~df.index.duplicated(), :]

            if x == 'SP500':
                #  bug with InsightsEntry. S&P500 dates are off by 1. eed to shift dates back if no beta calcultes incorrectly.
                l = pd.to_datetime(sdate) + pd.Timedelta(days=-1)
                d = get_sp500_as_df(l, edate)
                mult_df[x] = d[col_name]
            else:
                mask = (df.index >= sdate) & (df.index <= edate)
                d = df.loc[mask][col_name]
                mult_df[x] = d
        else:
            print (x + " not found")

    return mult_df

# %%
def get_return_defined_time(df, syear, smonth, sday, eyear, emonth, eday):
    # Create string representations for the dates
    start = f"{syear}-{smonth}-{sday}"
    end = f"{eyear}-{emonth}-{eday}"
    
    # Use a mask to grab data between defined dates
    mask = (df.index >= start) & (df.index <= end)
    
    # Get the mean of the column named daily return
    daily_ret = df.loc[mask]['daily_return'].mean()
    
    # Get the number of days between 2 dates
    df2 = df.loc[mask]
    days = df2.shape[0]

    # Return the total return between 2 dates
    return (days * daily_ret)

def get_roi_defined_time(df):
    # Set as a datetime
    # df['date'] = pd.to_datetime(df['date'])
    start_val = df.loc[S_DATE_STR:S_DATE_STR, 'close'].iloc[0]
    print("Initial Price :", start_val)
    
    # ----- I CHANGED THIS AFTER THE VIDEO -----
    
    end_val = df.loc[E_DATE_STR:E_DATE_STR, 'close'].iloc[0]
    print(end_val.item())
    print("Final Price :", end_val.item())
    
    # ----- END OF VIDEO CHANGES -----
    
    # Calculate return on investment
    roi = (end_val - start_val) / start_val

    # Return the total return between 2 dates
    return roi

# %%
    
def get_stock_mean_and_sd(stock_df, ticker):
    return stock_df[ticker].mean(), stock_df[ticker].std()

# Receives the dataframe with the stock ticker as the column name and
# the Adj Close values as the column data and returns the mean and 
# standard deviation
def get_mult_stock_mean_sd(stock_df):
    for stock in stock_df:
        mean, sd = get_stock_mean_and_sd(stock_df, stock)
        coeff_of_var = sd / mean
        print("Stock: {:10} Mean: {:7.2f} Standard deviation: {:2.2f}".format(stock, mean, sd))
        print("Coefficient of Variation: {}\n".format(coeff_of_var))

# Receives the dataframe with the Adj Close data and returns the coefficient of variation
def get_cov(stock_df):
    mean = stock_df['close'].mean()
    sd = stock_df['close'].std()
    cov = sd / mean
    return cov

# Receives a start and end date and returns the 1st date in that range
def get_valid_dates(df, sdate, edate):
    
    try:
        # mask = (df['date'] > sdate) & (df['date'] <= edate) 
        sm_df = df.loc[sdate:edate]
        if not sm_df.empty:
            sm_date = str(sm_df.index.min()).split(' ')[0]
            last_date = str(sm_df.index.max()).split(' ')[0]
            
            date_leading = str(sm_df.index.min()).split(' ')[0] #'-'.join(('0' if len(x) < 2 else '')+x for x in sm_date.split('-'))
            date_ending = str(sm_df.index.max()).split(' ')[0]  #'-'.join(('0' if len(x) < 2 else '')+x for x in last_date.split('-'))
            # print(date_leading, " ", date_ending)
        else:
            return None, None
    except Exception:
        print("Date Corrupted")
    else:
        return date_leading, date_ending


def roi_between_dates(df, sdate, edate):
    try: 
        start_val = df.loc[sdate,'close'] 
        end_val = df.loc[edate,'close']
        # print(f"start_val: {start_val}")
        # print(f"end_val: {end_val}")
        
        roi = ((end_val - start_val) / start_val)
    except Exception:
        print("Data Corrupted")
    else:
        return roi

def get_mean_between_dates(df, sdate, edate):
    mask = (df.index > sdate) & (df.index <= edate)    
    return df[mask]['close'].mean()

def get_sd_between_dates(df, sdate, edate):
    # mask = (df['Date'] > sdate) & (df['Date'] <= edate)
    mask = (df.index > sdate) & (df.index <= edate)
    return df[mask]["close"].std()

# get coeff of var
def get_cov_between_dates(df, sdate, edate):
    mean = get_mean_between_dates(df, sdate, edate)
    sd = get_sd_between_dates(df, sdate, edate)
    return sd / mean

def get_cov_ror(tickers, sdate = '2021-05-01', edate = '2026-05-01'):
    # Define column names for dataframe
    col_names = ["Ticker", "COV", "ROI"]
    
    # Create dataframe with column names
    df = pd.DataFrame(columns = col_names)
    
    for ticker in tickers:
        s_df = get_df_from_csv(ticker)
    
        sdate2, edate2 = get_valid_dates(s_df, sdate, edate)
    
        cov = get_cov_between_dates(s_df, sdate2, edate2)
    
        # Set date as index
        # s_df = s_df.set_index(['Date'])
        roi = roi_between_dates(s_df, sdate2, edate2)

        # Add stock data to new dataframe row
        # len provides the length of the dataframe which is the next open index
        df.loc[len(df.index)] = [ticker, cov, roi]
    
    return df

def get_rois_for_stocks(stock_df, sdate, edate):

    tickers = []
    rois = []
    c = []
    for index, row in stock_df.iterrows():
        df = get_df_from_csv(row['ticker'])
        if df is None:
            pass
        else:
            mask = (df.index > sdate) & (df.index <= edate)
            
            if len(df.loc[mask]) > 0:
                sdate, edate = get_valid_dates(df, sdate, edate)
                roi = roi_between_dates(df, sdate, edate)
                # if roi > 0:
                rois.append(roi)
                tickers.append(row['ticker'])
                c.append(row['company_name'])

    return pd.DataFrame({'Ticker' : tickers,  'Company': c , 'ROI' : rois})

# %% [markdown]
# ## Correlation

# %%
# sdate = '2025-01-03'
# edate = '2025-12-31'

# S_DATE_STR = '2020-01-03'
# E_DATE_STR = '2026-05-01'

# Remove CRC GRUB AAN ARNC
# market_df = get_cov_ror(top_1, '2024-01-03')
# market_df['beta'] = market_df.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
# market_df.sort_values(by=['beta'], ascending=False)
# print ('Std:', market_df['beta'].std())
# print('Mean: ', market_df['beta'].mean())
# market_df


mult_df = merge_df_by_column_name('daily_return','2024-01-03','2026-04-01',*top_1)
mult_df.corr().mean()
# Out:
# NVDA    0.358693
# META    0.376249
# AMZN    0.391519
# COST    0.290923
# JPM     0.376467
# LLY     0.238373
# GE      0.386291
# XOM     0.203830
# CEG     0.313832
# PLD     0.314261
# NUE     0.342143
# dtype: float64

# %%
sdate = '2025-01-03'
edate = '2025-12-31'

S_DATE_STR = '2025-01-03'
E_DATE_STR = '2025-12-31'

# # Remove CRC GRUB AAN ARNC
# market_df = get_cov_ror(top_2, '2024-01-03')
# market_df['beta'] = market_df.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
# market_df.sort_values(by=['beta'], ascending=False)
# print ('Std:', market_df['beta'].std())
# print('Mean: ', market_df['beta'].mean())
# market_df


mult_df = merge_df_by_column_name('daily_return','2023-01-03','2026-04-01',*top_2)
mult_df.corr().mean()
# Out:
# AVGO     0.348901
# GOOGL    0.305678
# TSLA     0.330855
# WMT      0.230395
# V        0.307958
# UNH      0.133644
# CAT      0.360498
# TPL      0.276866
# VST      0.321876
# DLR      0.317400
# FCX      0.343579
# dtype: float64

# %%
# sdate = '2025-01-03'
# edate = '2025-12-31'

# S_DATE_STR = '2025-01-03'
# E_DATE_STR = '2025-12-31'

market_df = get_cov_ror(top_3, '2024-01-03')
market_df['beta'] = market_df.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
market_df.sort_values(by=['beta'], ascending=False)
print ('Std:', market_df['beta'].std())
print('Mean: ', market_df['beta'].mean())
market_df
# mult_df = merge_df_by_column_name('daily_return','2023-01-03','2026-04-01',*top_3)
# mult_df.corr()
# Out:
# Std: 0.4611009699337368
# Mean:  1.146305539670192
#    Ticker       COV       ROI      beta
# 0    MSFT  0.101623  0.159737  1.129500
# 1    NFLX  0.257677  0.964339  1.627138
# 2      HD  0.071951  0.050915  1.028274
# 3      KO  0.093239  0.362558  0.336114
# 4      GS  0.288427  1.544603  1.296222
# 5    ISRG  0.131674  0.489523  1.559166
# 6     VRT  0.457187  5.712672  1.955399
# 7     SLB  0.144514  0.139458  0.730141
# 8     NEE  0.137905  0.650192  0.713286
# 9    EQIX  0.096604  0.460272  1.032363
# 10    SHW  0.069483  0.154361  1.201758

# %%
        
# stock_a = get_df_from_csv('AMZN')
# stock_a

# sdate, edate = get_valid_dates(stock_a, '2020-01-01','2020-12-31')
# print (sdate, edate)
# print ('mean:' , get_mean_between_dates(stock_a, sdate, edate))
# print ('sd:' , get_sd_between_dates(stock_a, sdate, edate))
# print ('cov:' , get_cov_between_dates(stock_a, sdate, edate))

# print ('roi ', roi_between_dates(stock_a, sdate, edate))




# #1 stocks in each sector
top_1 = [
    "NVDA",  # Technology
    "META",  # Communication Services
    "AMZN",  # Consumer Discretionary
    "COST",  # Consumer Staples
    "JPM",   # Financials
    "LLY",   # Healthcare
    "GE",    # Industrials
    "XOM",   # Energy
    "CEG",   # Utilities
    "PLD",   # Real Estate
    "NUE"    # Materials
]

# #2 stocks in each sector
top_2 = [
    "AVGO",  # Technology
    "GOOGL", # Communication Services
    "TSLA",  # Consumer Discretionary
    "WMT",   # Consumer Staples
    "V",     # Financials
    "UNH",   # Healthcare
    "CAT",   # Industrials
    "TPL",   # Energy
    "VST",   # Utilities
    "DLR",   # Real Estate
    "FCX"    # Materials
]

# #3 stocks in each sector
top_3 = [
    "MSFT",  # Technology
    "NFLX",  # Communication Services
    "HD",    # Consumer Discretionary
    "KO",    # Consumer Staples
    "GS",    # Financials
    "ISRG",  # Healthcare
    "VRT",   # Industrials
    "SLB",   # Energy
    "NEE",   # Utilities
    "EQIX",  # Real Estate
    "SHW"    # Materials
]



# plot_return_mult_stocks(100, df)

# # get_return_defined_time (stock_df, 2020, 1, 1, 2020, 12, 31)

# get_mult_stock_mean_sd(df)

# s,e = get_valid_dates(stock_df, S_DATE_DATETIME, E_DATE_STR)
# roi_between_dates(stock_df, S_DATE_STR, E_DATE_STR)

# get_cov_between_dates(stock_df, S_DATE_STR, E_DATE_STR)

# Correlation tells us how closely 2 stocks returns move together
# Correlation is a standardized value lying between -1 and 1
# When this value is greater that .5 we say that these stocks are strongly correlated
# Of course each stocks price is perfectly correlated with itself

# We focus on the correlation of returns because investors care about returns 

# faang_list = ["META", "AMZN", "AAPL", "NFLX", "GOOG"]
# mult_df = merge_df_by_column_name('daily_return',  '2020-1-1', '2020-12-31', *faang_list)
# mult_df

# # We can look at the correlation between Netflix and the others


# # We can plot this in a bar chart
# mult_df.corr()['NFLX'].plot(kind='bar')
# plt.show()


# Generate a Correlation Matrix
# mult_df.corr()

# mult_df.corr()['NFLX']

# Remember variance is a measure of how spread out a data set is
# Get Netflix variance
# mult_df['NFLX'].var()

# Annualize by getting the number of samples and multiply
# days = len(mult_df.index) # 253
# nflx_a_var = mult_df['ADP'].var() * days
# nflx_a_var

# %% [markdown]
# ## Variance

# %%
stock_a = get_df_from_csv('NVDA')
roi = get_roi_defined_time(stock_a)
print ("ROI:", roi)
# Out:
# Initial Price : 2.51207134
# 19.75275148
# Final Price : 19.75275148
# ROI: 6.863133170413864

# %% [markdown]
# ## Covariance
# ##### Covariance is the measure of the relationship between 2 blocks of data. The covariance of a stock to itself is the variance of that variable.

# %%
mult_df.cov() * 253
# Out:
#           META      AMZN      AAPL      NFLX      GOOG       ADP
# META  0.211498  0.121090  0.164972  0.122336  0.141870  0.116945
# AMZN  0.121090  0.148918  0.125881  0.121259  0.100904  0.069677
# AAPL  0.164972  0.125881  0.218563  0.121094  0.135036  0.133399
# NFLX  0.122336  0.121259  0.121094  0.214347  0.094115  0.074997
# GOOG  0.141870  0.100904  0.135036  0.094115  0.147431  0.116990
# ADP   0.116945  0.069677  0.133399  0.074997  0.116990  0.201566

# %%
mult_df.corr()
# Out:
#           META      AMZN      AAPL      NFLX      GOOG
# META  1.000000  0.682311  0.767307  0.574569  0.803420
# AMZN  0.682311  1.000000  0.697746  0.678707  0.680991
# AAPL  0.767307  0.697746  1.000000  0.559469  0.752260
# NFLX  0.574569  0.678707  0.559469  1.000000  0.529425
# GOOG  0.803420  0.680991  0.752260  0.529425  1.000000

# %% [markdown]
# ## Calculating a Portfolios Variance
# ###### When calculating the variance of a portfolio we must define its weight, or how much of the portfolio it makes up. If you add up the weight of all stocks you get a value of 1.
#
# ###### w_1, w_2 = Stock Weights
#
# ###### w_1, w_2 = Stock Standard Deviations
#
# ###### Portfolio Variance = (w_1*sigma_1 + w_2*sigma_2)^2
#
# ###### Since
#
# ###### Then the Portfolio Variance = w_1^2*sigma_1^2 + 2w_1*sigma_1w_2*sigma_2*rho_12 + w_2^2*sigma_2^2

# %%
port_list = ["META","NEM"]

port_df = merge_df_by_column_name('daily_return', '2020-01-01','2020-12-31', *port_list)

# port_df.corr()

price_df = merge_df_by_column_name('close', '2020-01-01','2020-12-31', *port_list)
price_df.head()
status
fb_price = 208.14
nm_price = 36.19
port_value = fb_price + (nm_price * 5)

fb_wt = fb_price / port_value
nm_wt = (nm_price * 5) / port_value

wts = np.array([fb_wt, nm_wt])
port_var = np.dot(wts.T, np.dot(port_df.cov() * 253, wts))
print ("Port Var: ", port_var)
print ("FB var : ", port_df['META'].var() * 253)
print ("NEM var : ", port_df['NEM'].var() * 253)
# Out:
# Port Var:  0.1277862257035596
# FB var :  0.2114976949437114
# NEM var :  0.2133476369891

# %% [markdown]
# ## Sectors

# %%
S_DATE_STR = '2024-01-01'
E_DATE_STR = '2025-12-31'
S_DATE_STR, E_DATE_STR
# Out:
# ('2024-01-01', '2025-12-31')

# %%
# S_DATE_STR = '2021-04-01'
# E_DATE_STR = '2026-04-30'

# sec_df = pd.read_csv(PATH + 'sector-stocks\stock_sectors.csv')

# sectors = [
#     "materials",
#     "communication-services",
#     "consumer-staples",
#     "consumer-discretionary",
#     "energy",
#     "financials",
#     "healthcare",
#     "industrials",
#     "real-estate",
#     "technology",
#     "utilities"
# ]

# indus_df = sec_df.loc[sec_df['Sector'] == "industrials"]
# health_df = sec_df.loc[sec_df['Sector'] == "healthcare"]
# it_df = sec_df.loc[sec_df['Sector'] == "technology"]
# comm_df = sec_df.loc[sec_df['Sector'] == "communication-services"]
# staple_df = sec_df.loc[sec_df['Sector'] == "consumer-staples"]
# discretion_df = sec_df.loc[sec_df['Sector'] == "consumer-discretionary"]
# utility_df = sec_df.loc[sec_df['Sector'] == "utilities"]
# financial_df = sec_df.loc[sec_df['Sector'] == "financials"]
# material_df = sec_df.loc[sec_df['Sector'] == "materials"]
# restate_df = sec_df.loc[sec_df['Sector'] == "real-estate"]
# energy_df = sec_df.loc[sec_df['Sector'] == "energy"]

# industrial = get_rois_for_stocks(indus_df, '2025-05-01','2026-05-01')
# health_care = get_rois_for_stocks(health_df, '2025-05-01','2026-05-01')
# it = get_rois_for_stocks(it_df, '2025-05-01','2026-05-01')
# discretion = get_rois_for_stocks(discretion_df, '2025-05-01','2026-05-01')
# commun = get_rois_for_stocks(comm_df, '2025-05-01','2026-05-01')
# staple = get_rois_for_stocks(staple_df, '2025-05-01','2026-05-01')
# utility = get_rois_for_stocks(utility_df, '2025-05-01','2026-05-01')
# finance = get_rois_for_stocks(financial_df, '2025-05-01','2026-05-01')
# material = get_rois_for_stocks(material_df, '2025-05-01','2026-05-01')
# restate = get_rois_for_stocks(restate_df, '2025-05-01','2026-05-01')
# energy = get_rois_for_stocks(energy_df, '2025-05-01','2026-05-01')

health_care['5year_beta'] = health_care.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
it['5year_beta'] = it.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
commun['5year_beta'] = commun.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
staple['5year_beta'] = staple.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
industrial['5year_beta'] = industrial.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
utility['5year_beta'] = utility.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
material['5year_beta'] = material.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
finance['5year_beta'] = finance.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
restate['5year_beta'] = restate.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
energy['5year_beta'] = energy.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
discretion['5year_beta'] = discretion.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)

# %%
def get_5_year_beta(ticker, sdate = '2021-05-01', edate = '2026-05-01'):

    try:
        
        sp_df = get_end_of_month_returns('SP500', sdate, edate)
        ticker_df = get_end_of_month_returns(ticker, sdate, edate)
        
        tickers = ['SP500', ticker]
        dfs = [sp_df, ticker_df]
        
        mult_df = pd.DataFrame()
        
        for index in range(len(tickers)):
            df = dfs[index]
            mult_df[tickers[index]] = df['daily_return']
        
        
        # Provides the covariance between the securities
        cov = mult_df.cov()
        
        # Get the covariance of the stock and the market
        cov_vs_market = cov.iloc[0,1]
        
        # Get annualized variance of the S&P
        sp_var = mult_df['SP500'].var()
        
        # Beta is normally calculated over a 5 year period which is why you may see a difference
        beta = cov_vs_market / sp_var
        
        return beta
    except Exception as e:
        print (f"Error in def get_5_year_beta({ticker}) {e}")
        return None

    
def get_end_of_month_returns(ticker, sdate = '2021-05-01', edate = '2026-05-01'):
    
    df = None
    last_month = 0
    last_month_index = None
    items = []

    try: 
        if ticker == 'SP500':
            df = get_sp500_as_df(sdate, edate)
        else:
            df = get_df_from_csv(ticker)
           
        for date in df.index:
            if last_month_index is not None:
                if last_month < date.month or last_year < date.year:
                    items.append({"date": last_month_index, "close": df[df.index == last_month_index].close.item()})
            
            last_month = date.month
            last_month_index = date
            last_year = date.year
            
        items.append({"date": df.index.max(), "close": df[df.index == df.index.max()].close.item()})
        df2 = pd.DataFrame(items)
        df2.set_index(['date'], inplace=True)
        df2['daily_return'] = (df2['close'] / df2['close'].shift(1)) - 1
        
        return df2
    except Exception as e:
        print (f"Error in def get_end_of_month_returns({ticker}). {e} {len(df)}")
        return None

# %%
if os.path.exists(PATH + '/downloaded/CRS.json'):
    os.remove(PATH + '/downloaded/CRS.json')
missing_tickers = ['ET', 'ETD']
download_tickers(0)
convert_files_json_to_csv(*missing_tickers)
add_daily_returns_to_stocks(*missing_tickers)
get_5_year_beta('CRS')
# Out:
# 200
# 1 - stock data for CRS saved.
# DONE DOWNLOADING!
# Converting json for CRS to csv
# Adding daily returns to CRS
# np.float64(1.3006611638169374)

# %%
df = industrial
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)  #& (df['Ticker'].isin(['HON','LMT','OTIS']))
df[mask].sort_values(by=['ROI'], ascending=False).head(20)


# industrial[industrial['Ticker'] == 'PSIX']
# industrial['5year_beta'] = industrial.apply(lambda row: get_5_year_beta(row['Ticker']), axis=1)
# Out:
#     Ticker                                          Company       ROI  \
# 2      GEV                                  GE Vernova Inc.  2.012667
# 17     CMI                                     Cummins Inc.  1.277985
# 52     EME                                EMCOR Group, Inc.  1.112787
# 51    ESLT                               Elbit Systems Ltd.  1.044303
# 14     PWR                            Quanta Services, Inc.  0.957620
# 15     FDX                                FedEx Corporation  0.885297
# 48     DAL                            Delta Air Lines, Inc.  0.679630
# 19     JCI               Johnson Controls International plc  0.654908
# 21     CSX                                  CSX Corporation  0.649969
# 13     HWM                            Howmet Aerospace Inc.  0.643694
# 9       PH                      Parker-Hannifin Corporation  0.617478
# 42    FERG                        Ferguson Enterprises Inc.  0.577208
# ...

# %%
df = discretion
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                             Company       ROI  5year_beta
# 76    FIVE                    Five Below, Inc.  2.187765    1.015013
# 428   KMRK    K-TECH Solutions Company Limited  1.280899    0.706466
# 430   VNCE                 Vince Holding Corp.  1.256281    0.666030
# 39     TPR                      Tapestry, Inc.  1.103651    1.480475
# 127    RSI       Rush Street Interactive, Inc.  1.018341    1.484539
# 86     BWA                     BorgWarner Inc.  0.983520    1.002093
# 35     VIK                 Viking Holdings Ltd  0.954801    0.893759
# 62     MGA            Magna International Inc.  0.828220    1.365053
# 481   LESL                      Leslie's, Inc.  0.826209    1.090830
# 138      M                        Macy's, Inc.  0.812272    1.456313
# 101    DDS                     Dillard's, Inc.  0.809094    1.242874
# 134     BC               Brunswick Corporation  0.782535    1.339621
# 19      GM              General Motors Company  0.771447    1.311946
# ...

# %%
df = restate
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                              Company       ROI  5year_beta
# 226   EUDA         EUDA Health Holdings Limited  0.897351    0.188294
# 43     AHR       American Healthcare REIT, Inc.  0.612503    0.595567
# 100   UNIT                     Uniti Group Inc.  0.541828    1.335945
# 30     HST          Host Hotels & Resorts, Inc.  0.517485    1.094880
# 25     JLL      Jones Lang LaSalle Incorporated  0.475271    1.355011
# 1      PLD                       Prologis, Inc.  0.432807    1.352275
# 35    AGNC                AGNC Investment Corp.  0.426053    1.352189
# 0     WELL                       Welltower Inc.  0.415195    0.805206
# 48    CTRE                 CareTrust REIT, Inc.  0.359959    0.733512
# 21     NLY      Annaly Capital Management, Inc.  0.340941    1.176232
# 4      SPG           Simon Property Group, Inc.  0.329233    1.337538
# 49      FR  First Industrial Realty Trust, Inc.  0.320352    1.050819
# ...

# %%
df = finance
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                                  Company       ROI  5year_beta
# 78     SHG        Shinhan Financial Group Co., Ltd.  0.935779    0.903130
# 10       C                           Citigroup Inc.  0.926415    1.152365
# 29      CM       Canadian Imperial Bank of Commerce  0.799162    0.951686
# 82     CFG           Citizens Financial Group, Inc.  0.791291    1.022463
# 80    NTRS               Northern Trust Corporation  0.785934    1.266730
# 69      KB                  KB Financial Group Inc.  0.784936    1.015886
# 74    IBKR          Interactive Brokers Group, Inc.  0.766950    1.234444
# 65     STT                 State Street Corporation  0.743909    1.444026
# 14     SAN                    Banco Santander, S.A.  0.731932    0.708319
# 13      TD                The Toronto-Dominion Bank  0.724402    0.616878
# 89     BAP                           Credicorp Ltd.  0.724284    0.953660
# 68     BBD                      Banco Bradesco S.A.  0.719151    0.538706
# ...

# %%
df = material
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                                   Company       ROI  5year_beta
# 33     ALB                     Albemarle Corporation  2.269617    1.333056
# 133   TROX                       Tronox Holdings plc  1.710345    0.840941
# 28     SQM  Sociedad QuÃ­mica y Minera de Chile S.A.  1.697964    0.936816
# 67    AUGO                        Aura Minerals Inc.  1.663650    0.123615
# 125   NEXA                       Nexa Resources S.A.  1.641208    0.603069
# 16      AU                     AngloGold Ashanti plc  1.606515    0.675348
# 74     ALM                   Almonty Industries Inc.  1.592222    0.725632
# 130   ELVR                    Elevra Lithium Limited  1.557601    0.354179
# 4      NEM                       Newmont Corporation  1.374615    0.438379
# 22     KGC                  Kinross Gold Corporation  1.321805    0.788586
# 12       B                Barrick Mining Corporation  1.290347    0.453141
# ...

# %%
df = utility
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#    Ticker                                            Company       ROI  \
# 40   ENLT                       Enlight Renewable Energy Ltd  1.479332
# 67   CTRI                             Centuri Holdings, Inc.  0.764347
# 63    KEN                                Kenon Holdings Ltd.  0.633227
# 16   AXIA                                    AXIA Energia SA  0.530815
# 0     NEE                               NextEra Energy, Inc.  0.492646
# 29    SBS  Companhia de Saneamento BÃ¡sico do Estado de S...  0.472958
# 85   NRGV                        Energy Vault Holdings, Inc.  0.398119
# 50  CIG.C      Companhia EnergÃ©tica de Minas Gerais - CEMIG  0.385147
# 73     HE                 Hawaiian Electric Industries, Inc.  0.315517
# 1     CEG                   Constellation Energy Corporation  0.309636
# 26    EIX                               Edison International  0.281673
# 74    HTO                                        H2O America  0.278379
# ...

# %%
df = health_care
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                       Company       ROI  5year_beta
# 119   IBRX             ImmunityBio, Inc.  2.861244    0.159208
# 159   DNTH   Dianthus Therapeutics, Inc.  1.186587    1.199855
# 45    RVMD    Revolution Medicines, Inc.  0.862823    1.090329
# 143   CGON             CG Oncology, Inc.  0.838947    0.362188
# 67    MRNA                 Moderna, Inc.  0.796446    1.147002
# 124   ACLX                 Arcellx, Inc.  0.793232    0.248202
# 180   TNGX      Tango Therapeutics, Inc.  0.637690    1.274014
# 132   CNTA  Centessa Pharmaceuticals plc  0.588330    1.219550
# 1      JNJ             Johnson & Johnson  0.514576    0.271490
# 19     GSK                       GSK plc  0.492561    0.474211
# 6      MRK             Merck & Co., Inc.  0.426660    0.209808
# 185    OGN                 Organon & Co.  0.399694    1.248690
# 4      AZN               AstraZeneca PLC  0.391412    0.406282
# 109   PCVX                 Vaxcyte, Inc.  0.391215    1.374707
# ...

# %%
df = it
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                                            Company        ROI  \
# 320   MGRT                       Mega Fortune Company Limited  28.106029
# 57    LITE                             Lumentum Holdings Inc.  12.766092
# 46    CIEN                                  Ciena Corporation   6.221756
# 31     GLW                               Corning Incorporated   2.842227
# 45     ASX                   ASE Technology Holding Co., Ltd.   2.515969
# 239   FSLY                                       Fastly, Inc.   2.135678
# 52      UI                                      Ubiquiti Inc.   2.116593
# 76    ALAB                                  Astera Labs, Inc.   1.853799
# 170   XNDU                Xanadu Quantum Technologies Limited   1.774038
# 93    TSEM                           Tower Semiconductor Ltd.   1.547722
# 75    FLEX                                          Flex Ltd.   1.458274
# 56    KEYS                        Keysight Technologies, Inc.   1.380995
# ...

# %%
df = commun
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                                Company       ROI  5year_beta
# 19    SATS                   EchoStar Corporation  4.278888    0.979797
# 45    GSAT                       Globalstar, Inc.  3.130589    1.445225
# 39    TIGO   Millicom International Cellular S.A.  1.754091    0.842275
# 0    GOOGL                          Alphabet Inc.  1.138823    1.157670
# 38     SKM                   SK Telecom Co., Ltd.  0.828878    0.712321
# 54    MSGS     Madison Square Garden Sports Corp.  0.720145    0.570818
# 26     VIV                TelefÃ´nica Brasil S.A.  0.715002    0.659458
# 18     VOD  Vodafone Group Public Limited Company  0.679748    0.445072
# 41    TIMB                               TIM S.A.  0.672710    0.456674
# 40     NYT             The New York Times Company  0.572336    1.063786
# 10     AMX        AmÃ©rica MÃ³vil, S.A.B. de C.V.  0.561125    0.688238
# 31     RCI             Rogers Communications Inc.  0.534099    0.672856
# ...

# %%
ticker= 'ETD'

if os.path.exists(PATH + f'/downloaded/{ticker}.json'):
    os.remove(PATH + f'/downloaded/{ticker}.json')
missing_tickers = [ticker]
download_tickers(0)
convert_files_json_to_csv(*missing_tickers)
add_daily_returns_to_stocks(*missing_tickers)
get_5_year_beta(ticker)

# get_end_of_month_returns(ticker)
# Out:
# 200
# 1 - stock data for ETD saved.
# DONE DOWNLOADING!
# Converting json for ETD to csv
# Adding daily returns to ETD
# np.float64(1.10569454425416)

# %%
df = staple
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                              Company       ROI  5year_beta
# 47     DAR             Darling Ingredients Inc.  0.838680    1.072208
# 39    COKE         Coca-Cola Consolidated, Inc.  0.651201    0.598982
# 29      BG                      Bunge Global SA  0.640604    0.629051
# 83    ANDE                  The Andersons, Inc.  0.548413    0.665355
# 22     ADM       Archer-Daniels-Midland Company  0.500032    0.536733
# 94     SPB       Spectrum Brands Holdings, Inc.  0.456985    0.600235
# 92     UTI  Universal Technical Institute, Inc.  0.450940    1.317357
# 7      BTI      British American Tobacco p.l.c.  0.423609    0.317104
# 33    USFD               US Foods Holding Corp.  0.405096    0.922323
# 13     TGT                   Target Corporation  0.402378    1.022907
# 80    UNFI           United Natural Foods, Inc.  0.396867    0.768042
# 28      DG           Dollar General Corporation  0.354681    0.313867
# ...

# %%
df = energy
mask = (df['5year_beta'] > .09) & (df['5year_beta'] < 1.5)
df[mask].sort_values(by=['ROI'], ascending=False).head(20)
# Out:
#     Ticker                              Company       ROI  5year_beta
# 83     SEI  Solaris Energy Infrastructure, Inc.  2.195380    1.084575
# 103    BTE                  Baytex Energy Corp.  1.897662    0.138660
# 96     LEU                 Centrus Energy Corp.  1.892531    1.353903
# 81    LBRT                  Liberty Energy Inc.  1.815926    0.469848
# 30     CCJ                   Cameco Corporation  1.689247    0.996309
# 68     RIG                      Transocean Ltd.  1.611111    1.374197
# 64    WFRD        Weatherford International plc  1.589081    0.851084
# 39     FTI                       TechnipFMC plc  1.589038    0.721830
# 70     VAL                      Valaris Limited  1.565120    1.011107
# 88     PBF                      PBF Energy Inc.  1.543480    0.251913
# 52     APA                      APA Corporation  1.424939    0.339605
# 92     TDW                       Tidewater Inc.  1.368745    0.568584
# ...

# %%
def get_sp500_as_df(start, end):
    sp_df = get_df_from_csv('SP500')
    sp_df = sp_df.loc[start:end]
    sp_df.index = sp_df.index + pd.Timedelta(days=1)
    return sp_df
    
def find_beta(ticker):
    # Tickers analyzed being the S&P and the stock passed
    port_list =['SP500']
    port_list.append(ticker)

    mult_df = merge_df_by_column_name('daily_return',  S_DATE_STR, 
                                  E_DATE_STR, *port_list)
    
    # Provides the covariance between the securities
    cov = mult_df.cov()
    
    # Get the covariance of the stock and the market
    cov_vs_market = cov.iloc[0,1]
    
    # Get annualized variance of the S&P
    sp_var = mult_df['SP500'].var()
    
    # Beta is normally calculated over a 5 year period which is why you may see a difference
    beta = cov_vs_market / sp_var
    return beta


beta = find_beta('AMD')
float(beta)
# Out:
# 2.126640498569942

# %% [markdown]
# ## Check for correlation

# %%
port_list = ["GNRC", "DXCM", "AMD", "NFLX", "COST", "TGT", "AES", "MSCI", 
             "NEM", "SBAC"]

mult_df =  merge_df_by_column_name('daily_return', '2023-01-01', E_DATE_STR, *port_list)
mult_df.corr()
# Out:
#           GNRC      DXCM       AMD      NFLX      COST       TGT       AES  \
# GNRC  1.000000  0.115376  0.337852  0.180947  0.177179  0.293046  0.264086
# DXCM  0.115376  1.000000  0.211657  0.175725  0.165825  0.138643  0.100469
# AMD   0.337852  0.211657  1.000000  0.357108  0.242323  0.181066  0.154636
# NFLX  0.180947  0.175725  0.357108  1.000000  0.312223  0.058200  0.085561
# COST  0.177179  0.165825  0.242323  0.312223  1.000000  0.215063  0.092513
# TGT   0.293046  0.138643  0.181066  0.058200  0.215063  1.000000  0.271377
# AES   0.264086  0.100469  0.154636  0.085561  0.092513  0.271377  1.000000
# MSCI  0.292359  0.138710  0.259275  0.208276  0.307815  0.236214  0.221994
# NEM   0.165232  0.066407  0.115467  0.134965  0.097798  0.096636  0.230213
# SBAC  0.164483  0.057770 -0.000194  0.032498  0.117425  0.197130  0.309701
#
#           MSCI       NEM      SBAC
# GNRC  0.292359  0.165232  0.164483
# DXCM  0.138710  0.066407  0.057770
# AMD   0.259275  0.115467 -0.000194
# ...

# %%
days = len(mult_df)
days
# Out:
# 1166

# %%
def get_stock_price_on_date(ticker, date):
    df = get_df_from_csv(ticker)
    return df.loc[date,'close']

p = get_stock_price_on_date('TGT', '2021-01-04')

p
# Out:
# np.float64(153.04923931)

# %%
# 01-04-2021 is the 1st date in 2021
print("GNRC $", get_stock_price_on_date('GNRC', '2021-01-04')) # 2 449.12
print("DXCM $", get_stock_price_on_date('DXCM', '2021-01-04')) # 1 357.74
print("AMD $", get_stock_price_on_date('AMD', '2021-01-04')) # 4 369.2
print("NFLX $", get_stock_price_on_date('NFLX', '2021-01-04')) # 1 522.86
print("COST $", get_stock_price_on_date('COST', '2021-01-04')) # 1 377.88
print("TGT $", get_stock_price_on_date('TGT', '2021-01-04')) # 3 527.46
print("AES $", get_stock_price_on_date('AES', '2021-01-04')) # 18 410.76
print("MSCI $", get_stock_price_on_date('MSCI', '2021-01-04')) # 1 435.40
print("NEM $", get_stock_price_on_date('NEM', '2021-01-04')) # 7 434.49
print("SBAC $", get_stock_price_on_date('SBAC', '2021-01-04')) # 2 548.84

# Total Investment
tot_inv = 449.12 + 357.74 + 369.2 + 522.86 + 377.88 + 527.46 + 410.76 + \
435.40 + 434.49 + 548.84
tot_inv
# Out:
# GNRC $ 224.56
# DXCM $ 89.435
# AMD $ 92.3
# NFLX $ 52.286
# COST $ 359.19775683
# TGT $ 153.04923931
# AES $ 19.1091822
# MSCI $ 414.13392885
# NEM $ 53.81930119
# SBAC $ 255.21338478
# 4433.750000000001

# %% [markdown]
# ## Return portfolio weight

# %%
def get_port_weight(price, total):
 return price / total

# %%
gnrc_w = get_port_weight(449.12, 4905.98)
dxcm_w = get_port_weight(357.74, 4905.98)
amd_w = get_port_weight(369.2, 4905.98)
nflx_w = get_port_weight(522.86, 4905.98)
cost_w = get_port_weight(377.88, 4905.98)
tgt_w = get_port_weight(527.46, 4905.98)
aes_w = get_port_weight(410.76, 4905.98)
msci_w = get_port_weight(435.40, 4905.98)
nem_w = get_port_weight(434.49, 4905.98)
sbac_w = get_port_weight(548.84, 4905.98)

wts = np.array([gnrc_w, dxcm_w, amd_w, nflx_w, cost_w, tgt_w, aes_w, msci_w, \
                nem_w, sbac_w])
wts

port_var = np.dot(wts.T, np.dot(mult_df.cov() * 756, wts))
print("Portfolio Covariance :", port_var)
print("GNRC Var :", mult_df["GNRC"].var() * 756)
print("NFLX Var :", mult_df["NFLX"].var() * 756)
# Out:
# Portfolio Covariance : 0.14095926175723578
# GNRC Var : 0.4394654211497731
# NFLX Var : 0.5476926564972349

# %% [markdown]
# ## Different Types of Risk

# %%
def calc_diversifiable_risk(df, tickers, weights):
    days = len(mult_df.index)
    port_covar = np.dot(weights.T, np.dot(df.cov() * days, weights))
    
    i = 0
    while i < len(tickers):
        wt_sq = weights[i] ** 2
        stk_var = mult_df[tickers[i]].var() * days
        wt_var = wt_sq * stk_var
        
        port_covar = port_covar - wt_var
        i += 1
        
    return port_covar

# %%
div_risk = calc_diversifiable_risk(mult_df, port_list, wts)
div_risk
# Out:
# np.float64(0.10354725856225301)

# %%
print("Systematic Risk :", (port_var - div_risk))
# Out:
# Systematic Risk : 0.037412003194982765
